# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 7
#       5 from sklearn import preprocessing
#       6 from sklearn.linear_model import SGDClassifier
# ----> 7 from sklearn.model_selection import train_test_split, GridSearchCV, GridSearch
#       8 from sklearn.preprocessing import StandardScaler, LabelEncoder
#      10 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ImportError: cannot import name 'GridSearch' from 'sklearn.model_selection' (/opt/anaconda3/envs/datascientest_3_12/lib/python3.12/site-packages/sklearn/model_selection/__init__.py)

# %%
df = pd.read_csv("../data/processed/compteur-classes-one-hot-encoded.csv", index_col = 0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1797907 entries, 12886 to 708012
# Columns: 109 entries, Jour to Comptage horaire
# dtypes: int64(108), object(1)
# memory usage: 1.5+ GB

# %%
y = df["Comptage horaire"]
X = df.drop(columns=["Comptage horaire"])

col_norm = ["Jour", "Mois", "Année", "Heure", "Jour_semaine", "Jour férié", "Vacances scolaires"]
encoder = preprocessing.OneHotEncoder(sparse_output=False, dtype=int) 

array = encoder.fit_transform(X[col_norm])

encoded_df_clean = pd.DataFrame(array, columns=encoder.get_feature_names_out(col_norm))

encoded_df_clean.index = X.index

X_clean = pd.concat([X.drop(columns=col_norm), encoded_df_clean], axis=1)

# %%
X_clean.head()
# Out:
#         Nom du compteur_10 avenue de la Grande Armée SE-NO  \
# 12886                                                   0
# 685401                                                  0
# 667057                                                  0
# 12622                                                   0
# 12680                                                   0
#
#         Nom du compteur_10 boulevard Auguste Blanqui NE-SO  \
# 12886                                                   0
# 685401                                                  0
# 667057                                                  0
# 12622                                                   0
# 12680                                                   0
#
#         Nom du compteur_102 boulevard de Magenta SE-NO  \
# 12886                                                0
# 685401                                               0
# 667057                                               0
# 12622                                                0
# 12680                                                0
#
#         Nom du compteur_106 avenue Denfert Rochereau NE-SO  \
# 12886                                                   1
# 685401                                                  0
# 667057                                                  0
# 12622                                                   1
# 12680                                                   1
#
#         Nom du compteur_129 rue Lecourbe SO-NE  \
# 12886                                        0
# 685401                                       0
# 667057                                       0
# 12622                                        0
# 12680                                        0
#
#         Nom du compteur_132 rue Lecourbe NE-SO  \
# 12886                                        0
# 685401                                       0
# 667057                                       0
# 12622                                        0
# 12680                                        0
#
#         Nom du compteur_135 avenue Daumesnil SE-NO  \
# 12886                                            0
# 685401                                           0
# 667057                                           0
# 12622                                            0
# 12680                                            0
#
#         Nom du compteur_147 avenue d'Italie S-N  \
# 12886                                         0
# 685401                                        0
# 667057                                        0
# 12622                                         0
# 12680                                         0
#
#         Nom du compteur_152 boulevard du Montparnasse E-O  \
# 12886                                                   0
# 685401                                                  0
# 667057                                                  0
# 12622                                                   0
# 12680                                                   0
#
#         Nom du compteur_152 boulevard du Montparnasse O-E  ...  \
# 12886                                                   0  ...
# 685401                                                  0  ...
# 667057                                                  0  ...
# 12622                                                   0  ...
# 12680                                                   0  ...
#
#         Jour_semaine_2  Jour_semaine_3  Jour_semaine_4  Jour_semaine_5  \
# 12886                0               1               0               0
# 685401               0               0               0               0
# 667057               1               0               0               0
# 12622                0               0               0               1
# 12680                0               0               0               1
#
#         Jour_semaine_6  Jour_semaine_7  Jour férié_0  Jour férié_1  \
# 12886                0               0             1             0
# 685401               0               1             1             0
# 667057               0               0             1             0
# 12622                0               0             1             0
# 12680                0               0             1             0
#
#         Vacances scolaires_0  Vacances scolaires_1
# 12886                      1                     0
# 685401                     0                     1
# 667057                     1                     0
# 12622                      1                     0
# 12680                      1                     0
#
# [5 rows x 182 columns]

# %%
label_enc = LabelEncoder()
y = label_enc.fit_transform(y)

# %%
y
# Out:
# array([4, 4, 4, ..., 0, 0, 0])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_clean, y, test_size=0.2, random_state=42)

# %%
# TODO test without encoding but with StandardScaler

# %%
params = {
    'loss': ['hinge'],
    # 'squared_error', 'huber', 'epsilon_insensitive'
    'alpha': 10.0**-np.arange(1,7),
}

# %%
sgd = SGDClassifier(loss='hinge')
clf = GridSearchCV(sgd, params, scoring='accuracy', n_jobs=-1, verbose=2)
clf.fit(X_train, y_train)
print("best params", clf.best_params_)
print("best score", clf.best_score_)
print("train score", clf.score(X_train, y_train))
print("test score", clf.score(X_test, y_test))
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ..............................alpha=0.1, loss=hinge; total time=42.5min
# [CV] END ...........................alpha=0.0001, loss=hinge; total time=50.4min
# [CV] END .............................alpha=0.01, loss=hinge; total time=42.5min
# [CV] END ...........................alpha=0.0001, loss=hinge; total time=50.5min
# [CV] END .............................alpha=0.01, loss=hinge; total time=42.5min
# [CV] END ............................alpha=1e-05, loss=hinge; total time=75.8min
# [CV] END ..............................alpha=0.1, loss=hinge; total time=42.5min
# [CV] END ............................alpha=1e-05, loss=hinge; total time=75.8min
# [CV] END ............................alpha=0.001, loss=hinge; total time=47.9min
# [CV] END ............................alpha=1e-05, loss=hinge; total time=73.3min
# [CV] END ............................alpha=0.001, loss=hinge; total time=47.8min
# [CV] END ............................alpha=1e-05, loss=hinge; total time=73.4min
# [CV] END ..............................alpha=0.1, loss=hinge; total time=42.5min
# [CV] END ............................alpha=0.001, loss=hinge; total time=44.1min
# [CV] END ............................alpha=1e-05, loss=hinge; total time=48.1min
# best params {'alpha': 0.001, 'loss': 'hinge'}
# best score 0.27715502407314063
# train score 0.27067735039021085
# test score 0.2695268394969715
# [CV] END .............................alpha=0.01, loss=hinge; total time=42.5min
# [CV] END ............................alpha=0.001, loss=hinge; total time=44.6min
# [CV] END ............................alpha=1e-06, loss=hinge; total time=74.8min
# [CV] END ..............................alpha=0.1, loss=hinge; total time=42.4min
# [CV] END ............................alpha=0.001, loss=hinge; total time=44.6min
# [CV] END ............................alpha=1e-06, loss=hinge; total time=75.0min
# [CV] END ..............................alpha=0.1, loss=hinge; total time=42.5min
# [CV] END ...........................alpha=0.0001, loss=hinge; total time=50.3min
# [CV] END ............................alpha=1e-06, loss=hinge; total time=69.3min
# [CV] END .............................alpha=0.01, loss=hinge; total time=42.5min
# [CV] END ...........................alpha=0.0001, loss=hinge; total time=50.2min
# [CV] END ............................alpha=1e-06, loss=hinge; total time=69.4min
# [CV] END .............................alpha=0.01, loss=hinge; total time=42.5min
# [CV] END ...........................alpha=0.0001, loss=hinge; total time=50.1min
# [CV] END ............................alpha=1e-06, loss=hinge; total time=69.5min

# %%
params = {
    'loss': ['log_loss', 'modified_huber'],
    # 'squared_error', 'huber', 'epsilon_insensitive'
    'alpha': 10.0**-np.arange(2,5),
}

sgd = SGDClassifier()
clf = GridSearchCV(sgd, params, scoring='accuracy', n_jobs=-1, verbose=2)
clf.fit(X_train, y_train)
print("best params", clf.best_params_)
print("best score", clf.best_score_)
print("train score", clf.score(X_train, y_train))
print("test score", clf.score(X_test, y_test))
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END .........................alpha=0.001, loss=log_loss; total time=46.2min
# [CV] END ...................alpha=0.001, loss=modified_huber; total time=46.7min
# [CV] END ....................alpha=0.01, loss=modified_huber; total time=46.3min
# [CV] END ...................alpha=0.001, loss=modified_huber; total time=46.8min
# [CV] END ....................alpha=0.01, loss=modified_huber; total time=46.3min
# [CV] END ........................alpha=0.0001, loss=log_loss; total time=47.0min
# [CV] END ....................alpha=0.01, loss=modified_huber; total time=46.5min
# [CV] END ........................alpha=0.0001, loss=log_loss; total time=47.0min
# [CV] END ....................alpha=0.01, loss=modified_huber; total time=46.4min
# [CV] END ........................alpha=0.0001, loss=log_loss; total time=47.2min
# [CV] END ....................alpha=0.01, loss=modified_huber; total time=46.5min
# [CV] END ........................alpha=0.0001, loss=log_loss; total time=47.1min
# [CV] END ..........................alpha=0.01, loss=log_loss; total time=40.0min
# [CV] END .........................alpha=0.001, loss=log_loss; total time=46.0min
# [CV] END ........................alpha=0.0001, loss=log_loss; total time=22.8min
# best params {'alpha': 0.0001, 'loss': 'log_loss'}
# best score 0.3501712060904177
# train score 0.35201015069612224
# test score 0.35126897341913665
